# %%
a,b = map(int, input().split())
C = (a+b)*2
S = a*b
print(f"Chu vi cua HCN: {C}")
print(f"Dien tich cua HCN: {S}")
# Out:
# Chu vi cua HCN: 18
# Dien tich cua HCN: 20

# %%
a=int(input("ban kinh"))
C=2*3.14*a
S=3.14*(a^2)
print(f"chu vi:{C:.2f}")
print(f"dien tich:{S:.2f}")
# Out:
# chu vi:31.40
# dien tich:21.98

# %%
a,b,c =map(int, input("3 canh cua tam giac: ").split())
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
        print("tam giac deu")
    elif a==b or a==c or b==c:
        print("tam giac can")
    elif a^2 +b^2 =c^2 or a^2+ c^2=b^2 or b^2 +c^2 =a^2
    print(" day la tam giac vuong")
else:
