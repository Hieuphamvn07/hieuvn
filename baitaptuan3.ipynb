# %% [markdown]
# Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau

# %%
n = int (input())
m = 0
while (n>0):
    m = n%10 +m*10
    n//=10
    print (m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 n = int (input())
#       2 m = 0
#       3 while (n>0):
#
# ValueError: invalid literal for int() with base 10: ''

# %%
num = int(input())
if num % 2 ==0:
    print("chan")
else :
    print("le")
# Out:
# chan

# %%
he_so = 10 ** k
tam = int(n * he_so + 0.5)
ket_qua = tam / he_so
so_can_lam_tron = float(input("nhap vao so thuc: "))
k = int(input("nhap so chu so muon giu lai (k): "))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 he_so = 10 ** k
#       2 tam = int(n * he_so + 0.5)
#       3 ket_qua = tam / he_so
#
# NameError: name 'k' is not defined
